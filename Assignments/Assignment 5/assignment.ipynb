# %% [markdown]
# # Loyola University Chicago
# ## Department of Computer Science
# ### COMP 272: Data Structures II (Spring 2026)
#
# # Assignment 5: Hashing
# **Dr. Karima Ennaoui**
# *(Originally created by Dr. William O’Connell)*
#
# **This is an individual assignment.**
#
# **Deadline:** Wednsday, March 18, 2026, 11:55 PM.

# %% [markdown]
# ## Submission Instructions
#
# Submit your work through **Sakai** by uploading the edited source files:
#
# - `HashingProblems.java`
# - `myHashMap.java`

# %% [markdown]
# ## Part 1 — Hash Map Object Implementation using Separate Chaining (50 points)
#
# Complete the following methods in `myHashMap.java`:
#
# - `remove(K)`
# - `remove(K, V)`
# - `replace(K, V)`
# - `replace(K, V, V)`
#
# Full documentation is provided in the `myHashMap.java` starter code.
#
# The `myHashMap` object provided to you represents a simplified version of Java’s built-in `HashMap` implementation. It uses the **Separate Chaining** hashing approach. Your task is to enhance this simplified implementation so that its behavior matches that of the Java Collections Framework class for the methods listed above.

# %% [markdown]
# ### Scoring
#
# - Passing the `remove(K)` and `remove(K, V)` tests — **25 points**
# - Passing `replace(K, V)` and `replace(K, V, V)` tests — **25 points**

# %% [markdown]
# ## Part 2 — Hashing Problems (50 points)
#
# While Part 1 focuses on implementing a simplified `HashMap`, these exercises use Java’s built-in `HashMap` object.
#
# Implement the following methods in `HashingProblems.java`.

# %% [markdown]
# ### 1. `getAverage` (15 points)
#
# Compute the average of the values corresponding to all keys that appear both in the array and in the `HashMap`.

# %% [markdown]
# ### 2. `odd` (10 points)
#
# Return an `ArrayList` containing the values associated with **odd keys** in the `HashMap`.

# %% [markdown]
# ### 3. `twoSums` (25 points)
#
# Given an integer array and an integer `k`, count how many **pairs of elements** have a difference `k`.
#
# Implement this with time complexity **O(n)** using a `HashMap` or `HashSet`.

# %% [markdown]
# ## Additional Notes
#
# 1. Before submitting, ensure that your code passes all tests in `Main.java`. Additional hidden tests may also be used for grading.
# 2. Include your **name** and **course section number** as comments at the top of both files.
