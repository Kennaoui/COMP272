# %% [markdown]
# # COMP 272 – Final Review
#
# This notebook summarizes the main ideas from the COMP 272 final study guide and connects them to the types of reasoning needed for the final exam.
#
# These are not copies of the exam questions. They are review prompts, applied examples, and code-style questions designed to help you recognize the same concepts in different forms.
#
# **How to use this review:**
#
# - Read the concept summary first.
# - Try the questions before discussing the answers.
# - Focus on the reasoning behind each answer, not only the final choice.

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Priority Queue (PQ): Remove by Priority, Not Arrival Order
#
# -> A priority queue removes elements according to priority, not insertion order.
#
# -> For a min-priority queue, removeMin returns the item with the smallest priority.
#
# -> Main operations: insert, removeMin, and peek.
#
# -> A binary heap is a common efficient implementation.
#
# ---
#
# **1.** Which operation best captures the behavior of a min-priority queue?
#
# A. enqueue
#
# B. removeMin
#
# C. push
#
# D. contains
#
# **2.** Insert priorities 8, 3, 10, 1 into a min-priority queue. Which priority is removed first?
#
# **3.** A hospital triage desk receives patients in arrival order, but more urgent patients must be seen first. Why is a regular queue not the correct ADT here?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Binary Heap: Shape and Heap-Order Invariants
#
# -> A binary heap is a complete binary tree.
#
# -> In a min-heap, each parent is less than or equal to its children.
#
# -> The heap is not fully sorted; it only guarantees local parent-child order.
#
# -> Both invariants matter: shape makes array storage efficient, and order makes removeMin correct.
#
# ---
#
# **1.** Which statement must always be true in a min-heap?
#
# A. The array is fully sorted.
#
# B. Every parent is less than or equal to its children.
#
# C. Every left child is smaller than every right child.
#
# D. The largest value is always the rightmost leaf.
#
# **2.** Given the array [2, 5, 3, 9, 7], does it satisfy the min-heap property? Explain briefly.
#
# **4.** What would break if the heap-order property holds, but the tree is not complete?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Array Representation of a Heap
#
# -> Heaps are commonly stored in arrays.
#
# -> For index i: left child = 2i + 1, right child = 2i + 2.
#
# -> For index i: parent = (i - 1) // 2.
#
# -> Array representation avoids explicit parent/child pointers and improves practical efficiency.
#
# ---
#
# **1.** Fill in the blank: The left child of index i is at index ______.
#
# **2.** In a heap array, what are the children of the node at index 3?
#
# **3.** Which is a primary advantage of array-based heap representation?
#
# A. It makes arbitrary search O(1).
#
# B. It avoids storing child pointers.
#
# C. It makes the array fully sorted.
#
# D. It removes the need for heap-order.
#
# **4.** In the array [1, 4, 3, 10, 6, 8, 5], identify the parent of the element at index 5.
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Heap Operations: insert, removeMin, peek
#
# -> insert adds the new element at the end, then bubbles up.
#
# -> removeMin removes the root, moves the last element to the root, then bubbles down.
#
# -> peek returns the root without removing it.
#
# -> insert and removeMin are O(log n); peek is O(1).
#
# ---
#
# **1.** After inserting a new small value into a min-heap, why might it need to bubble up?
#
# **2.** After removing the root from a min-heap, why do we move the last element to the root before bubbling down?
#
# **3.** Exam-style: After deleting the root from a min-heap, the last value is moved to the root. What determines which child it swaps with during heapify-down?
#
# **4.** If a heap has n elements and we call removeMin repeatedly until empty, what sorting-related process are we performing?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Heapify: Building a Heap Bottom-Up
#
# -> Heapify builds a heap from an existing array.
#
# -> It starts from the last non-leaf node and works backward toward the root.
#
# -> Heapify runs in O(n), not O(n log n).
#
# -> This is different from inserting n elements one by one.
#
# ---
#
# **1.** Heapify starts at:
#
# A. the root
#
# B. the last element
#
# C. the last non-leaf node
#
# D. the minimum value
#
# **2.** Fill in the blank: In an array of size n, the last non-leaf node is at index ______.
#
# **3.** Why is heapify O(n) even though a single bubble-down can take O(log n)?
#
# **4.**  : Explain why leaves do not need to be heapified individually.
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Heap Limitation: Searching Is Inefficient
#
# -> A heap gives fast access to the minimum or maximum.
#
# -> A heap is only partially ordered.
#
# -> Searching for an arbitrary value can require checking many nodes.
#
# -> Arbitrary search in a heap is O(n).
#
# ---
#
# **1.** Why is searching for a random value inefficient in a heap?
#
# **2.** Which structure is generally better for ordered searching: heap or BST?
#
# **3.**  : If the root of a min-heap is 3 and you are searching for value 50, can you discard either the left or right subtree the way you might in a BST? Explain.
#
# **4.** Which operation is the heap specifically optimized for?
#
# A. find arbitrary element
#
# B. remove minimum or maximum
#
# C. binary search
#
# D. preserve insertion order
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Hash Table: Key to Index Mapping
#
# -> A hash table maps keys to table indices.
#
# -> Expected search, insert, and remove are O(1).
#
# -> This depends on good distribution and controlled load factor.
#
# -> Worst-case performance can degrade to O(n).
#
# ---
#
# **1.** Why are hash table operations expected to be O(1)?
#
# **2.** With a very poor hash function, worst-case search in a hash table of n items can become:
#
# A. O(1)
#
# B. O(log n)
#
# C. O(n)
#
# D. O(n log n)
#
# **3.**    Describe a concrete situation in which a hash table behaves like a linked list.
#
# **4.** If the table has 1000 buckets but all keys map to bucket 0, what happens to expected performance?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Hash Function Design
#
# -> A hash function maps a key to a number.
#
# -> A good hash function is deterministic.
#
# -> A good hash function distributes keys uniformly.
#
# -> A good hash function is efficient to compute and maps to a valid range after compression.
#
# ---
#
# **1.** Which is NOT a desirable property of a hash function?
#
# A. deterministic
#
# B. uniform distribution
#
# C. slow computation
#
# D. efficient computation
#
# **2.** Name two properties of a good hash function and explain why they matter.
#
# **3.** Why can summing ASCII values be a poor hash function for strings?
#
# **4.**  : Which is likely worse: using only the first character of a string, or using a polynomial accumulation hash? Explain briefly.
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Compression Function and Table Indices
#
# -> A raw hash value may be too large to use directly as an index.
#
# -> Compression maps a hash value into the table range.
#
# -> A common compression method is h(k) = k mod N.
#
# -> The table size can influence collision patterns.
#
# ---
#
# **1.** If h(k) = k mod 7, where does key 31 go?
#
# **2.** If h(k) = k mod 10, why do keys 10, 20, and 30 collide?
#
# **3.**    Why might choosing table sizes carefully matter for hash table performance?
#
# **4.** Fill in the blank: Compression ensures that the hash value becomes a valid ______.
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Load Factor and Rehashing
#
# -> Load factor α = number of elements / table capacity.
#
# -> As α increases, collisions usually increase.
#
# -> High load factor can hurt expected search and insert performance.
#
# -> Rehashing creates a larger table and reinserts the elements.
#
# ---
#
# **1.** A table has 10 buckets and 8 elements. Compute the load factor.
#
# **2.** A table has 10 buckets and grows from 5 to 9 elements. What happens to the load factor and expected performance?
#
# **3.** When load factor becomes too high, what action should be taken and why?
#
# **4.**    Rehashing costs O(n). Why can it still be a good strategy?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Separate Chaining
#
# -> Separate chaining stores colliding entries in a bucket structure such as a list.
#
# -> Performance depends on the length of the chains.
#
# -> Chaining can handle more elements than buckets, but long chains degrade performance.
#
# -> It is one major collision-resolution strategy.
#
# ---
#
# **1.** Insert keys 8, 15, and 22 using h(k) = k mod 7 with separate chaining. Which bucket do they share?
#
# **2.** Which statement is true?
#
# A. Separate chaining stores all values directly in table slots only.
#
# B. Separate chaining stores colliding values in an external structure.
#
# C. Separate chaining prevents collisions.
#
# D. Separate chaining guarantees O(1) worst-case search.
#
# **3.** Why does a long chain make search slower?
#
# **4.**    If each bucket uses a linked list, what happens to search time when all keys collide into one bucket?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Open Addressing
#
# -> Open addressing stores all elements directly in the table array.
#
# -> When a collision occurs, the algorithm probes for another slot.
#
# -> Open addressing requires empty slots to work correctly.
#
# -> Linear probing, quadratic probing, and double hashing are forms of open addressing.
#
# ---
#
# **1.** Select all true statements:
#
# A. Open addressing stores elements directly in the table array.
#
# B. Open addressing uses chains at each bucket.
#
# C. Open addressing requires probing after collisions.
#
# D. Open addressing needs at least one empty slot.
#
# **2.** Why must an open addressing table have an empty slot?
#
# **3.** How is open addressing different from separate chaining?
#
# **4.**    Why can deletion be more delicate in open addressing than in separate chaining?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Linear Probing and Other Probing Techniques
#
# -> Linear probing checks the next slot after a collision.
#
# -> Linear probing can create clustering.
#
# -> Quadratic probing uses jumps such as 1, 4, 9, 16, ...
#
# -> Double hashing uses a second hash function to determine the step size.
#
# ---
#
# **1.** Insert 10, 17, 24, 31 into a table of size 7 using h(k) = k mod 7 and linear probing. Show the final positions.
#
# **2.** What is the main issue that may arise with linear probing?
#
# A. recursion
#
# B. clustering
#
# C. sorting
#
# D. disconnected components
#
# **3.** Fill in the blank: Quadratic probing uses increments based on ______ numbers.
#
# **4.**    Why can clustering make future insertions slower even if some empty slots still exist?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Bloom Filter
#
# -> A Bloom filter is a memory-efficient membership filter.
#
# -> It uses a bit array and multiple hash functions.
#
# -> It may produce false positives.
#
# -> It does not produce false negatives.
#
# ---
#
# **1.** Bloom filters guarantee:
#
# A. no false positives
#
# B. no false negatives
#
# C. exact storage of all keys
#
# D. no hash collisions
#
# **2.** If a Bloom filter says “not present,” what can we conclude?
#
# **3.** Why are Bloom filters more space-efficient than hash tables?
#
# **4.** A system first checks whether a request might be flagged, then performs expensive verification only if needed. Why is a Bloom filter appropriate for the first step?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Cuckoo Hashing
#
# -> Each key has multiple possible positions.
#
# -> These positions are determined by multiple hash functions.
#
# -> Insertion may displace an existing key.
#
# -> Cycles may require rehashing.
#
# ---
#
# **1.** Fill in the blanks: Each key has ______ possible positions determined by ______ hash functions.
#
# **2.** When inserting a key causes a collision in its primary location, what happens next?
#
# A. The key is stored in a linked list.
#
# B. The occupant may be kicked out and moved to its alternate location.
#
# C. The key is ignored.
#
# D. The table is sorted.
#
# **3.** Why can cuckoo hashing require rehashing?
#
# **4.**    Explain how a cycle can happen during repeated displacements.
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Sorting: Algorithm Choice and Comparison Lower Bound
#
# -> Sorting algorithm choice depends on data size, existing order, stability, and memory constraints.
#
# -> The best possible worst-case time for comparison-based sorting is O(n log n).
#
# -> MergeSort, HeapSort, and well-balanced QuickSort reach O(n log n) behavior in important cases.
#
# -> Some algorithms are better for nearly sorted data.
#
# ---
#
# **1.** What is the best possible worst-case complexity of a comparison-based sorting algorithm?
#
# A. O(n)
#
# B. O(log n)
#
# C. O(n log n)
#
# D. O(n²)
#
# **2.** Give one sorting algorithm covered in class that achieves O(n log n).
#
# **3.** For a very large but mostly sorted dataset, which sorting idea is attractive and why?
#
# **4.**    Why does the comparison-based lower bound not necessarily apply to non-comparison sorts?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Selection Sort
#
# -> Selection sort repeatedly selects the minimum remaining element.
#
# -> It is simple but usually inefficient for large inputs.
#
# -> Its time complexity is O(n²).
#
# -> It does not significantly benefit from already sorted input.
#
# ---
#
# **1.** What does selection sort do during each pass?
#
# **2.** Why is selection sort O(n²)?
#
# **3.** If the input is already sorted, does selection sort become O(n)? Explain.
#
# **4.**    Compare selection sort and insertion sort on nearly sorted input.
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Insertion Sort
#
# -> Insertion sort builds a sorted prefix one element at a time.
#
# -> It is adaptive: efficient for small or nearly sorted data.
#
# -> Best case is O(n), worst case is O(n²).
#
# -> The inner loop shifts elements until the correct position is found.
#
# ---
#
# **1.** Fill in the missing condition:
#
# ```java
# while (j >= 0 && __________) {
#     arr[j + 1] = arr[j];
#     j--;
# }
# ```
#
# **2.** Why is insertion sort efficient when the array is mostly sorted?
#
# **3.** For [2, 3, 4, 5, 1], why does insertion sort perform many shifts near the end?
#
# **4.**    In insertion sort, what property is maintained before each outer-loop iteration?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## QuickSort
#
# -> QuickSort chooses a pivot and partitions around it.
#
# -> Average time is O(n log n).
#
# -> Worst-case time is O(n²).
#
# -> Pivot choice strongly affects performance.
#
# ---
#
# **1.** If the first element is always chosen as pivot and the array is already sorted, what can happen to performance?
#
# **2.** Give one alternative pivot-selection strategy that can reduce the chance of bad partitions.
#
# **3.** Consider [6, 2, 9, 1, 5] with first element as pivot. Which values are less than the pivot?
#
# **4.**    Why do unbalanced partitions lead to deeper recursion?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## MergeSort, HeapSort, Shell Sort, and TimSort
#
# -> MergeSort has guaranteed O(n log n) time but uses extra memory.
#
# -> HeapSort uses heap operations to repeatedly remove min or max.
#
# -> Shell Sort improves insertion sort using gaps.
#
# -> TimSort exploits existing order in real data and uses insertion/merge ideas.
#
# ---
#
# **1.** Which algorithm is preferable when guaranteed O(n log n) behavior is more important than in-place behavior: MergeSort or basic QuickSort?
#
# **2.** How is HeapSort related to priority queues?
#
# **3.** Why do gaps help Shell Sort reduce large shifts early?
#
# **4.**    Why is TimSort effective on real-world data that often contains already sorted runs?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Graph Basics: Vertices, Edges, Direction, and Cycles
#
# -> A graph has vertices and edges.
#
# -> Edges may be directed or undirected.
#
# -> A graph is acyclic if it has no cycles.
#
# -> In directed graphs, direction matters when determining whether a cycle exists.
#
# ---
#
# **1.** What is the difference between a directed and an undirected graph?
#
# **2.** What does it mean for a graph to be acyclic?
#
# **3.** Can a directed graph have edges that visually form a loop-like shape but still be acyclic? Explain.
#
# **4.**    Why is cycle detection different in directed and undirected graphs?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Adjacency Matrix
#
# -> An adjacency matrix uses a 2D matrix to represent edges.
#
# -> Space complexity is O(n²).
#
# -> Edge lookup is fast.
#
# -> It can waste memory for sparse graphs.
#
# ---
#
# **1.** What does matrix[i][j] represent?
#
# **2.** Why is the space complexity O(n²)?
#
# **3.** For an undirected graph, what symmetry should appear in the adjacency matrix?
#
# **4.** Exam-style: Given four vertices, why would an adjacency matrix always have 16 entries even if the graph has only 3 edges?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Adjacency List
#
# -> An adjacency list stores only existing neighbors.
#
# -> Space complexity is O(n + m).
#
# -> It is usually better for sparse graphs.
#
# -> It avoids storing absent edges.
#
# ---
#
# **1.** If m is much smaller than n², which representation is more space-efficient?
#
# A. adjacency matrix
#
# B. adjacency list
#
# C. both always equal
#
# D. neither
#
# **2.** Why does adjacency list avoid storing many non-edges?
#
# **3.** Give one advantage of adjacency matrix over adjacency list.
#
# **4.**    For graph traversal, why is adjacency list often more efficient than scanning an entire matrix row?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## BFS: Breadth-First Search
#
# -> BFS explores level by level.
#
# -> BFS uses a queue.
#
# -> BFS finds shortest paths in unweighted graphs.
#
# -> A visited set prevents repeated processing.
#
# ---
#
# **1.** Which data structure does BFS use?
#
# A. stack
#
# B. queue
#
# C. heap
#
# D. priority queue
#
# **2.** Why does BFS find the shortest path in an unweighted graph?
#
# **3.** Code-style: In BFS, when should a neighbor usually be marked visited: when enqueued or when removed from the queue? Why?
#
# **4.**    If neighbor order is left-to-right, why must the neighbor order be specified to predict the exact BFS order?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## DFS: Depth-First Search
#
# -> DFS explores deeply before backtracking.
#
# -> DFS uses a stack or recursion.
#
# -> DFS can be used for reachability and structural exploration.
#
# -> DFS does not guarantee shortest paths.
#
# ---
#
# **1.** Which data structure naturally matches DFS behavior?
#
# A. queue
#
# B. stack
#
# C. heap
#
# D. hash table
#
# **2.** Why does DFS not guarantee the shortest path?
#
# **3.** Code-style: What is the role of this line in DFS or BFS?
#
# ```java
# visited.add(v);
# ```
#
# **4.**    If DFS is implemented recursively, where is the stack being used?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## BFS vs DFS Traversal Order
#
# -> Traversal order depends on the start vertex.
#
# -> Traversal order depends on neighbor order.
#
# -> BFS visits close vertices before farther ones.
#
# -> DFS follows one path deeply before backtracking.
#
# ---
#
# **1.** Why can BFS and DFS produce different orders even from the same starting vertex?
#
# **2.** Given a graph, what information must be specified to determine one exact traversal order?
#
# **3.** If you only need to know whether a path exists, could either BFS or DFS work? Explain.
#
# **4.**    Why does BFS naturally give distance layers while DFS does not?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Spanning Subgraph and Spanning Tree
#
# -> A subgraph uses vertices and edges from the original graph.
#
# -> A spanning subgraph includes all vertices.
#
# -> A spanning tree is connected, acyclic, and includes all vertices.
#
# -> A tree with n vertices has n - 1 edges.
#
# ---
#
# **1.** Fill in the blank: A spanning subgraph must include all ______.
#
# **2.** Fill in the blank: A spanning tree must be connected and ______.
#
# **3.** For n vertices, how many edges does a tree have?
#
# **4.**    Why does adding one extra edge to a spanning tree create a cycle?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Code-Style: Hash Table Reasoning
#
# -> Implementation questions often test whether you understand how operations behave.
#
# -> Hash-table code depends on hashing, compression, collision handling, and equality checks.
#
# -> Small code snippets may ask you to identify behavior, output, or bugs.
#
# ---
#
# **1.** What is printed?
#
# ```java
# int M = 7;
# int[] keys = {10, 17, 24};
# for (int k : keys) {
#     System.out.print((k % M) + " ");
# }
# ```
#
# **2.** In a separate chaining table, what could go wrong if search only checks the first node in a chain?
#
# **3.**    In open addressing, why is it not always safe to simply set a deleted slot to empty?
#
# **4.** Code-style: What operation is being performed by this loop?
#
# ```java
# while (table[index] != null) {
#     index = (index + 1) % table.length;
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Code-Style: Graph Traversal Reasoning
#
# -> BFS and DFS implementations differ mainly in the structure used to store frontier vertices.
#
# -> A queue leads to BFS behavior.
#
# -> A stack or recursion leads to DFS behavior.
#
# -> The visited set is essential for correctness on graphs with cycles.
#
# ---
#
# **1.** What traversal does this suggest?
#
# ```java
# Queue<Vertex> q = new LinkedList<>();
# q.add(start);
# while (!q.isEmpty()) {
#     Vertex v = q.remove();
#     // visit neighbors
# }
# ```
#
# **2.** What traversal does this suggest?
#
# ```java
# void visit(Vertex v) {
#     visited.add(v);
#     for (Vertex w : neighbors(v)) {
#         if (!visited.contains(w)) visit(w);
#     }
# }
# ```
#
# **3.**    What bug could occur if we never check whether a neighbor has already been visited?
#
# **4.** If the goal is shortest path in an unweighted graph, which of these two code patterns is more appropriate?
#
# </div>

# %% [markdown]
# <div style="border:2px solid #444; border-radius:10px; padding:15px; margin:14px 0;">
#
# ## Mixed Structure and Algorithm Choice
#
# -> Use hashing for fast lookup by key.
#
# -> Use heaps for repeated access to min or max priority.
#
# -> Use BFS for shortest paths in unweighted graphs.
#
# -> Use sorting when the whole collection needs to be ordered.
#
# ---
#
# **1.** You need to quickly check whether a name exists in a large collection. Which structure is appropriate?
#
# **2.** You need to repeatedly remove the smallest task. Which structure is appropriate?
#
# **3.** You need the shortest path between two vertices in an unweighted graph. Which algorithm is appropriate?
#
# **4.**    You need to process millions of requests and quickly reject those definitely not in a flagged set using little memory. Which structure is most appropriate?
#
# </div>
